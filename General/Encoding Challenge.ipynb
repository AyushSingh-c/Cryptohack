# %%
#port comms
from Crypto.Util.number import bytes_to_long, long_to_bytes
import base64
import codecs
import random
import telnetlib
import json

HOST = "socket.cryptohack.org"
PORT = 13377

tn = telnetlib.Telnet(HOST, PORT)

def readline():
    return tn.read_until(b"\n")

def json_recv():
    line = readline()
    return json.loads(line.decode())

def json_send(hsh):
    request = json.dumps(hsh).encode()
    tn.write(request)
    
for i in range(100):
    received = json_recv()

    print("Received type: ",received["type"])
    print("Received encoded value: ",received["encoded"])

    if received["type"] == "base64":
        encoded = base64.b64decode(received["encoded"].encode()).decode() # wow so encode
    elif received["type"] == "hex":
        encoded = bytearray.fromhex(received["encoded"]).decode()
    elif received["type"] == "rot13":
        encoded = codecs.decode(received["encoded"], 'rot_13')
    elif received["type"] == "bigint":
        encoded = bytearray.fromhex(received["encoded"][2:]).decode()
    elif received["type"] == "utf-8":
        encoded = "".join([chr(b) for b in received["encoded"]])
    print("value", encoded,i)
    to_send = {
        "decoded": encoded
    }
    json_send(to_send)
    
received = json_recv()

print("Received type: ",received["flag"])
# Out:
# Received type:  base64
# Received encoded value:  bWF1aV9tdWNoX2ZyYXNlcg==
# value maui_much_fraser 0
# Received type:  bigint
# Received encoded value:  0x636f6d706c6963617465645f696461686f5f6869676873
# value complicated_idaho_highs 1
# Received type:  bigint
# Received encoded value:  0x73706563746163756c61725f7370656172735f726566657272616c
# value spectacular_spears_referral 2
# Received type:  rot13
# Received encoded value:  gunvynaq_ghavat_vzcyrzragvat
# value thailand_tuning_implementing 3
# Received type:  bigint
# Received encoded value:  0x6d6f6f6e5f7662756c6c6574696e5f6f75747374616e64696e67
# value moon_vbulletin_outstanding 4
# Received type:  utf-8
# Received encoded value:  [106, 101, 114, 114, 121, 95, 99, 111, 112, 101, 95, 108, 111, 118, 101, 100]
# value jerry_cope_loved 5
# Received type:  hex
# Received encoded value:  6576616c5f6564745f6879706f746865736973
# value eval_edt_hypothesis 6
# Received type:  base64
# Received encoded value:  cHVyY2hhc2VkX21hcmtldHNfZWRpdG9y
# value purchased_markets_editor 7
# Received type:  utf-8
# Received encoded value:  [112, 101, 97, 99, 101, 95, 110, 101, 119, 115, 108, 101, 116, 116, 101, 114, 115, 95, 115, 104, 111, 112, 112, 101, 114]
# value peace_newsletters_shopper 8
# Received type:  base64
# Received encoded value:  YWxpX2Rvc2FnZV9qYXZhc2NyaXB0
# value ali_dosage_javascript 9
# Received type:  rot13
# Received encoded value:  ernqvat_nhgbzngvp_ivgnzvaf
# value reading_automatic_vitamins 10
# Received type:  rot13
# Received encoded value:  jrrxyl_enqne_whql
# value weekly_radar_judy 11
# Received type:  base64
# Received encoded value:  Y29uZG9fanVuY3Rpb25fc2xlZXBz
# value condo_junction_sleeps 12
# Received type:  hex
# Received encoded value:  62726f746865725f766173745f6c656e64657273
# value brother_vast_lenders 13
# Received type:  bigint
# Received encoded value:  0x7368616d655f666f756e645f6161726f6e
# value shame_found_aaron 14
# Received type:  hex
# Received encoded value:  706c6174666f726d5f686f74656c735f68696c6c73
# value platform_hotels_hills 15
# Received type:  rot13
# Received encoded value:  onax_zbqrengbef_ubpxrl
# value bank_moderators_hockey 16
# Received type:  base64
# Received encoded value:  ZGVlcGVyX2NvbnRyaWJ1dGVfcmFwaWQ=
# value deeper_contribute_rapid 17
# Received type:  bigint
# Received encoded value:  0x73776974636865645f64765f72656468656164
# value switched_dv_redhead 18
# Received type:  rot13
# Received encoded value:  fvqr_pbyyrpgvba_cnpxvat
# value side_collection_packing 19
# Received type:  hex
# Received encoded value:  747275737465645f736f6d6574696d65735f63656c656273
# value trusted_sometimes_celebs 20
# Received type:  bigint
# Received encoded value:  0x6474735f726561725f6d72
# value dts_rear_mr 21
# Received type:  base64
# Received encoded value:  cGxlZGdlX2Jsb2dnZXJzX3NpbXM=
# value pledge_bloggers_sims 22
# Received type:  base64
# Received encoded value:  c2FzX2xhenlfYWRtaW5pc3RyYXRvcnM=
# value sas_lazy_administrators 23
# Received type:  rot13
# Received encoded value:  cebgrpgrq_fgenvtug_cebsrffvbany
# value protected_straight_professional 24
# Received type:  base64
# Received encoded value:  YmFyYmllX3ByZXZpb3VzX2NyaW1lcw==
# value barbie_previous_crimes 25
# Received type:  base64
# Received encoded value:  ZGlzdHJpYnV0b3JfbGF1bmRyeV9zZW5zZQ==
# value distributor_laundry_sense 26
# Received type:  bigint
# Received encoded value:  0x676574735f6c6f61645f6c616e6573
# value gets_load_lanes 27
# Received type:  utf-8
# Received encoded value:  [97, 98, 97, 110, 100, 111, 110, 101, 100, 95, 119, 95, 104, 101, 97, 116, 104, 101, 114]
# value abandoned_w_heather 28
# Received type:  utf-8
# Received encoded value:  [114, 102, 95, 97, 110, 97, 108, 121, 115, 116, 95, 118, 105, 99, 116, 105, 109, 115]
# value rf_analyst_victims 29
# Received type:  utf-8
# Received encoded value:  [99, 111, 108, 108, 101, 99, 116, 105, 110, 103, 95, 115, 117, 103, 103, 101, 115, 116, 105, 111, 110, 95, 115, 105, 116, 117, 97, 116, 105, 111, 110, 115]
# value collecting_suggestion_situations 30
# Received type:  hex
# Received encoded value:  6c61777965725f737065636965735f6c6f7665
# value lawyer_species_love 31
# Received type:  base64
# Received encoded value:  dmVybm9uX251cnNlX3BlcnNvbg==
# value vernon_nurse_person 32
# Received type:  rot13
# Received encoded value:  vagrerfgvat_ovbybtl_znelynaq
# value interesting_biology_maryland 33
# Received type:  rot13
# Received encoded value:  nqzva_tbbq_oenir
# value admin_good_brave 34
# Received type:  base64
# Received encoded value:  ZmlnaHRlcnNfZW1iYXNzeV9jZXJ0YWlu
# value fighters_embassy_certain 35
# Received type:  utf-8
# Received encoded value:  [115, 116, 101, 97, 108, 95, 106, 97, 110, 117, 97, 114, 121, 95, 99, 117, 115, 116, 111, 109, 105, 122, 101, 100]
# value steal_january_customized 36
# Received type:  base64
# Received encoded value:  ZGF0ZXNfY3JpdGljc190dQ==
# value dates_critics_tu 37
# Received type:  bigint
# Received encoded value:  0x6d6f7573655f696e766f6c76656d656e745f7365656473
# value mouse_involvement_seeds 38
# Received type:  hex
# Received encoded value:  666f7274756e655f706970656c696e655f7468656d
# value fortune_pipeline_them 39
# Received type:  base64
# Received encoded value:  ZGljdGlvbmFyeV9hbnRhcmN0aWNhX2hs
# value dictionary_antarctica_hl 40
# Received type:  base64
# Received encoded value:  Y19kZWFsdGltZV9hYnJvYWQ=
# value c_dealtime_abroad 41
# Received type:  rot13
# Received encoded value:  urnqref_yrnqre_hagb
# value headers_leader_unto 42
# Received type:  hex
# Received encoded value:  646965645f6e765f696e64756374696f6e
# value died_nv_induction 43
# Received type:  bigint
# Received encoded value:  0x617761726465645f77697a6172645f61726d7374726f6e67
# value awarded_wizard_armstrong 44
# Received type:  base64
# Received encoded value:  ZXhwb3J0c19taW5pbWl6ZV9kaWZmcw==
# value exports_minimize_diffs 45
# Received type:  hex
# Received encoded value:  62656c6c795f6465636973696f6e5f636f6e766572746564
# value belly_decision_converted 46
# Received type:  bigint
# Received encoded value:  0x726f6164735f6575725f6b656e7961
# value roads_eur_kenya 47
# Received type:  bigint
# Received encoded value:  0x6f786964655f636f6e76656e74696f6e616c5f73706563
# value oxide_conventional_spec 48
# Received type:  base64
# Received encoded value:  aWN0X2FzcF9qdXN0aWZ5
# value ict_asp_justify 49
# Received type:  base64
# Received encoded value:  c3dpbmdlcnNfZ2RwX3BsYXllZA==
# value swingers_gdp_played 50
# Received type:  hex
# Received encoded value:  6e61727261746976655f72696368617264735f6d7573696369616e
# value narrative_richards_musician 51
# Received type:  rot13
# Received encoded value:  pneybf_erfgnhenagf_ernqre
# value carlos_restaurants_reader 52
# Received type:  rot13
# Received encoded value:  gblf_frffvbaf_pvivyvna
# value toys_sessions_civilian 53
# Received type:  bigint
# Received encoded value:  0x7075626c69636174696f6e735f7a75735f6d6175726974697573
# value publications_zus_mauritius 54
# Received type:  base64
# Received encoded value:  cmV0YWluX2JhX3RyYWRlbWFyaw==
# value retain_ba_trademark 55
# Received type:  base64
# Received encoded value:  bWxiX2ZvYW1fdmVuaWNl
# value mlb_foam_venice 56
# Received type:  rot13
# Received encoded value:  orunivbhe_nhgbzbovyr_gevavgl
# value behaviour_automobile_trinity 57
# Received type:  base64
# Received encoded value:  cmlkZV90aW1famVhbg==
# value ride_tim_jean 58
# Received type:  base64
# Received encoded value:  dG93ZXJzX2JsYWRlc19wcmVyZXF1aXNpdGU=
# value towers_blades_prerequisite 59
# Received type:  hex
# Received encoded value:  73686f636b5f70726f6f665f706f6c696365
# value shock_proof_police 60
# Received type:  hex
# Received encoded value:  6d617267696e5f686f6c64656d5f69636f6e73
# value margin_holdem_icons 61
# Received type:  rot13
# Received encoded value:  yriryf_qbfr_tbvat
# value levels_dose_going 62
# Received type:  rot13
# Received encoded value:  snibevgrf_qvssreraprf_pbzsbeg
# value favorites_differences_comfort 63
# Received type:  bigint
# Received encoded value:  0x72617465735f6d696e655f666c6f6f72696e67
# value rates_mine_flooring 64
# Received type:  bigint
# Received encoded value:  0x6d6f6e69746f725f6b656c6b6f6f5f737475636b
# value monitor_kelkoo_stuck 65
# Received type:  bigint
# Received encoded value:  0x666f7274795f656e636c6f7365645f74616c6b73
# value forty_enclosed_talks 66
# Received type:  bigint
# Received encoded value:  0x6561726e65645f73706972697475616c5f686f706573
# value earned_spiritual_hopes 67
# Received type:  bigint
# Received encoded value:  0x706f7374706f737465645f6e696765725f6669667479
# value postposted_niger_fifty 68
# Received type:  bigint
# Received encoded value:  0x6465706172746d656e74616c5f696e766974655f7465656e73
# value departmental_invite_teens 69
# Received type:  base64
# Received encoded value:  ZWZfcHJldmlld3NfcG9zc2libGU=
# value ef_previews_possible 70
# Received type:  bigint
# Received encoded value:  0x66696e64735f657874656e6465645f706572696f64
# value finds_extended_period 71
# Received type:  rot13
# Received encoded value:  ov_fninaanu_ynetryl
# value bi_savannah_largely 72
# Received type:  base64
# Received encoded value:  aWNvbnNfZW1pbmVtX2xhbmNhc3Rlcg==
# value icons_eminem_lancaster 73
# Received type:  hex
# Received encoded value:  6e61746976655f6f63636173696f6e5f63696e67756c6172
# value native_occasion_cingular 74
# Received type:  hex
# Received encoded value:  6c65735f6d6f74656c5f6469727479
# value les_motel_dirty 75
# Received type:  utf-8
# Received encoded value:  [109, 97, 110, 95, 101, 120, 112, 101, 114, 116, 95, 118, 101, 114, 100, 101]
# value man_expert_verde 76
# Received type:  rot13
# Received encoded value:  pvivyvmngvba_cebcre_evpuzbaq
# value civilization_proper_richmond 77
# Received type:  utf-8
# Received encoded value:  [104, 111, 117, 115, 101, 95, 99, 97, 112, 101, 95, 109, 97, 115, 115, 97, 99, 104, 117, 115, 101, 116, 116, 115]
# value house_cape_massachusetts 78
# Received type:  base64
# Received encoded value:  ZGl2aW5nX2R1dGllc19wdWJsaXNo
# value diving_duties_publish 79
# Received type:  hex
# Received encoded value:  6f6f5f616d6269656e5f656e636f7572616765
# value oo_ambien_encourage 80
# Received type:  utf-8
# Received encoded value:  [101, 109, 112, 104, 97, 115, 105, 115, 95, 99, 104, 114, 111, 110, 105, 99, 95, 112, 114, 111, 118, 105, 110, 99, 105, 97, 108]
# value emphasis_chronic_provincial 81
# Received type:  bigint
# Received encoded value:  0x6d6f64735f7374617465645f7472616e736c6174696f6e
# value mods_stated_translation 82
# Received type:  hex
# Received encoded value:  706f65745f73746166665f7265706c69636174696f6e
# value poet_staff_replication 83
# Received type:  bigint
# Received encoded value:  0x746f7572735f636f6c6c696e735f626f6174696e67
# value tours_collins_boating 84
# Received type:  hex
# Received encoded value:  737469636b6572735f7076635f726f636b73
# value stickers_pvc_rocks 85
# Received type:  rot13
# Received encoded value:  ynl_cnffcbeg_yvirf
# value lay_passport_lives 86
# Received type:  hex
# Received encoded value:  6c65676974696d6174655f726964655f67756172616e74656573
# value legitimate_ride_guarantees 87
# Received type:  base64
# Received encoded value:  ZmFuY3lfbnN3X2VtcGxveWVl
# value fancy_nsw_employee 88
# Received type:  base64
# Received encoded value:  ZmFjaW5nX3Bpbmtfc3ltYW50ZWM=
# value facing_pink_symantec 89
# Received type:  utf-8
# Received encoded value:  [100, 111, 95, 119, 97, 116, 99, 104, 101, 115, 95, 103, 101, 110, 100, 101, 114]
# value do_watches_gender 90
# Received type:  base64
# Received encoded value:  c2hvY2tfbmF0aW9uX21pY3Jvd2F2ZQ==
# value shock_nation_microwave 91
# Received type:  base64
# Received encoded value:  dGhyb3VnaF9hbGljZV9mcmVl
# value through_alice_free 92
# Received type:  rot13
# Received encoded value:  snezref_fhozvffvbaf_fryyref
# value farmers_submissions_sellers 93
# Received type:  bigint
# Received encoded value:  0x72656d61696e735f6578706572696d656e74735f6e6174696f6e73
# value remains_experiments_nations 94
# Received type:  hex
# Received encoded value:  68617264776f6f645f6e61727261746976655f61646f7074
# value hardwood_narrative_adopt 95
# Received type:  rot13
# Received encoded value:  xnafnf_yraf_grrantr
# value kansas_lens_teenage 96
# Received type:  bigint
# Received encoded value:  0x636972637569745f62617468735f626c6f6f6d62657267
# value circuit_baths_bloomberg 97
# Received type:  base64
# Received encoded value:  YmFsdGltb3JlX3Jlc2VydmVfYmFzaW4=
# value baltimore_reserve_basin 98
# Received type:  rot13
# Received encoded value:  qrne_pyrnevat_tragyl
# value dear_clearing_gently 99
# Received type:  crypto{3nc0d3_d3c0d3_3nc0d3}
