# %%
#port comms
from Crypto.Util.number import bytes_to_long, long_to_bytes
import base64
import codecs
import random
import telnetlib
import json

HOST = "socket.cryptohack.org"
PORT = 13377

tn = telnetlib.Telnet(HOST, PORT)

def readline():
    return tn.read_until(b"\n")

def json_recv():
    line = readline()
    return json.loads(line.decode())

def json_send(hsh):
    request = json.dumps(hsh).encode()
    tn.write(request)
    
for i in range(100):
    received = json_recv()

    print("Received type: ",received["type"])
    print("Received encoded value: ",received["encoded"])

    if received["type"] == "base64":
        encoded = base64.b64decode(received["encoded"].encode()).decode() # wow so encode
    elif received["type"] == "hex":
        encoded = bytearray.fromhex(received["encoded"]).decode()
    elif received["type"] == "rot13":
        encoded = codecs.decode(received["encoded"], 'rot_13')
    elif received["type"] == "bigint":
        encoded = bytearray.fromhex(received["encoded"][2:]).decode()
    elif received["type"] == "utf-8":
        encoded = "".join([chr(b) for b in received["encoded"]])
    print("value", encoded,i)
    to_send = {
        "decoded": encoded
    }
    json_send(to_send)
    
received = json_recv()

print("Received type: ",received["flag"])
# Out:
# /tmp/ipykernel_7595/1599712767.py:6: DeprecationWarning: 'telnetlib' is deprecated and slated for removal in Python 3.13
#   import telnetlib
# Received type:  rot13
# Received encoded value:  pnfgyr_qrcraqrapr_zbhagnvaf
# value castle_dependence_mountains 0
# Received type:  utf-8
# Received encoded value:  [100, 105, 112, 95, 105, 110, 116, 101, 114, 118, 101, 110, 116, 105, 111, 110, 115, 95, 115, 118]
# value dip_interventions_sv 1
# Received type:  utf-8
# Received encoded value:  [99, 104, 97, 114, 109, 95, 100, 105, 112, 95, 100, 105, 112]
# value charm_dip_dip 2
# Received type:  base64
# Received encoded value:  ZHJpdmluZ19hY2NfcXVhbGlmaWVk
# value driving_acc_qualified 3
# Received type:  base64
# Received encoded value:  cnVnX2Nvb2xfdHJhdW1h
# value rug_cool_trauma 4
# Received type:  rot13
# Received encoded value:  sn_nppbzcyvfurq_cvpxvat
# value fa_accomplished_picking 5
# Received type:  hex
# Received encoded value:  74616b696e675f6d62615f64656e766572
# value taking_mba_denver 6
# Received type:  utf-8
# Received encoded value:  [97, 108, 108, 111, 121, 95, 99, 97, 109, 101, 114, 111, 111, 110, 95, 112, 108, 97, 121]
# value alloy_cameroon_play 7
# Received type:  rot13
# Received encoded value:  fzbbgu_arjfcncre_crefbanyvmrq
# value smooth_newspaper_personalized 8
# Received type:  utf-8
# Received encoded value:  [114, 101, 119, 97, 114, 100, 115, 95, 99, 114, 101, 97, 116, 105, 111, 110, 115, 95, 115, 99, 114, 105, 112, 116, 115]
# value rewards_creations_scripts 9
# Received type:  base64
# Received encoded value:  cG90ZW50aWFsX2FtZXJpY2Fuc19hc3N1bWVz
# value potential_americans_assumes 10
# Received type:  utf-8
# Received encoded value:  [116, 101, 108, 101, 112, 104, 111, 110, 101, 95, 109, 105, 100, 100, 108, 101, 95, 100, 111, 105, 110, 103]
# value telephone_middle_doing 11
# Received type:  base64
# Received encoded value:  Ym9vbV9tZW1vcnlfcmF0aGVy
# value boom_memory_rather 12
# Received type:  hex
# Received encoded value:  6167677265676174655f726f7365735f636f6d626174
# value aggregate_roses_combat 13
# Received type:  hex
# Received encoded value:  616e696d616c5f6172697a6f6e615f6c6963656e736573
# value animal_arizona_licenses 14
# Received type:  rot13
# Received encoded value:  cebqhpgvba_uhznavgl_pbzcyrgryl
# value production_humanity_completely 15
# Received type:  utf-8
# Received encoded value:  [99, 117, 114, 114, 101, 110, 116, 108, 121, 95, 114, 101, 102, 114, 101, 115, 104, 95, 106, 117, 110, 103, 108, 101]
# value currently_refresh_jungle 16
# Received type:  utf-8
# Received encoded value:  [102, 111, 114, 95, 98, 97, 114, 101, 95, 101, 108, 101, 99, 116, 114, 111, 110, 105, 99]
# value for_bare_electronic 17
# Received type:  utf-8
# Received encoded value:  [115, 97, 118, 97, 103, 101, 95, 97, 100, 118, 101, 114, 116, 95, 111, 108, 121, 109, 112, 105, 99, 115]
# value savage_advert_olympics 18
# Received type:  base64
# Received encoded value:  cmVmdXNlZF9mYXVsdF9oaXJl
# value refused_fault_hire 19
# Received type:  bigint
# Received encoded value:  0x6c696b656c69686f6f645f746578747572655f696e6372656173696e67
# value likelihood_texture_increasing 20
# Received type:  rot13
# Received encoded value:  gbhef_pbafgenvag_ybat
# value tours_constraint_long 21
# Received type:  hex
# Received encoded value:  646965735f636f616c5f73616464616d
# value dies_coal_saddam 22
# Received type:  rot13
# Received encoded value:  yyblq_ertvba_vfb
# value lloyd_region_iso 23
# Received type:  bigint
# Received encoded value:  0x6661696c735f6e6577746f6e5f72656369706573
# value fails_newton_recipes 24
# Received type:  bigint
# Received encoded value:  0x7370615f77696c6465726e6573735f6361726566756c6c79
# value spa_wilderness_carefully 25
# Received type:  bigint
# Received encoded value:  0x657863656c6c656e745f636f75706c655f6c696273
# value excellent_couple_libs 26
# Received type:  rot13
# Received encoded value:  fnyyl_cbjrerq_qvfpynvzre
# value sally_powered_disclaimer 27
# Received type:  utf-8
# Received encoded value:  [116, 104, 101, 114, 97, 112, 101, 117, 116, 105, 99, 95, 115, 117, 115, 101, 95, 117, 112, 103, 114, 97, 100, 101, 115]
# value therapeutic_suse_upgrades 28
# Received type:  hex
# Received encoded value:  726f6f6d6d6174655f7370656e64696e675f6c696b656c79
# value roommate_spending_likely 29
# Received type:  base64
# Received encoded value:  d2Vla19zdG9tYWNoX3RyYWNrZWQ=
# value week_stomach_tracked 30
# Received type:  utf-8
# Received encoded value:  [104, 111, 115, 116, 115, 95, 102, 111, 114, 103, 111, 116, 116, 101, 110, 95, 102, 105, 120, 101, 115]
# value hosts_forgotten_fixes 31
# Received type:  rot13
# Received encoded value:  sngr_qvfpergr_chyfr
# value fate_discrete_pulse 32
# Received type:  base64
# Received encoded value:  cGVuYWx0eV9rYXRoeV9jb21iaW5hdGlvbg==
# value penalty_kathy_combination 33
# Received type:  utf-8
# Received encoded value:  [115, 111, 95, 98, 101, 99, 97, 109, 101, 95, 97, 110, 116, 97, 114, 99, 116, 105, 99, 97]
# value so_became_antarctica 34
# Received type:  rot13
# Received encoded value:  olr_pbnfg_qvfphff
# value bye_coast_discuss 35
# Received type:  utf-8
# Received encoded value:  [103, 105, 97, 110, 116, 95, 115, 101, 108, 101, 99, 116, 105, 110, 103, 95, 101, 110, 116, 105, 116, 105, 101, 115]
# value giant_selecting_entities 36
# Received type:  rot13
# Received encoded value:  terngyl_obeqref_gnkv
# value greatly_borders_taxi 37
# Received type:  base64
# Received encoded value:  aW5jbHVkaW5nX3Bvd2Vyc2VsbGVyX21hcmN1cw==
# value including_powerseller_marcus 38
# Received type:  utf-8
# Received encoded value:  [112, 101, 97, 115, 95, 100, 114, 97, 109, 97, 95, 114, 111, 108, 101, 115]
# value peas_drama_roles 39
# Received type:  base64
# Received encoded value:  Y29uc19jb21tdW5pdGllc19ib25l
# value cons_communities_bone 40
# Received type:  base64
# Received encoded value:  c3RyYWlnaHRfa2VudHVja3lfdG91cmlzbQ==
# value straight_kentucky_tourism 41
# Received type:  hex
# Received encoded value:  68756d69646974795f7465726d696e6f6c6f67795f646f77
# value humidity_terminology_dow 42
# Received type:  rot13
# Received encoded value:  snibhevgr_oybbq_oybpxf
# value favourite_blood_blocks 43
# Received type:  rot13
# Received encoded value:  qveg_ynql_ebfgre
# value dirt_lady_roster 44
# Received type:  rot13
# Received encoded value:  tbguvp_guerngf_abgrf
# value gothic_threats_notes 45
# Received type:  bigint
# Received encoded value:  0x616c6d6f73745f636972636c65735f68616e67696e67
# value almost_circles_hanging 46
# Received type:  hex
# Received encoded value:  64675f636f6c6f6e69616c5f737461746963
# value dg_colonial_static 47
# Received type:  bigint
# Received encoded value:  0x726570726573656e746174696f6e5f74726561745f636f6c6c656374696f6e73
# value representation_treat_collections 48
# Received type:  utf-8
# Received encoded value:  [109, 105, 115, 116, 97, 107, 101, 115, 95, 99, 97, 116, 99, 104, 95, 118, 105, 101, 110, 110, 97]
# value mistakes_catch_vienna 49
# Received type:  bigint
# Received encoded value:  0x616d6f756e74735f707265706172655f666c7578
# value amounts_prepare_flux 50
# Received type:  rot13
# Received encoded value:  vax_zvahgrf_nccf
# value ink_minutes_apps 51
# Received type:  bigint
# Received encoded value:  0x736865666669656c645f666f726265735f6d7572726179
# value sheffield_forbes_murray 52
# Received type:  base64
# Received encoded value:  dG9rZW5fc29ueV9pbmNlbnRpdmU=
# value token_sony_incentive 53
# Received type:  rot13
# Received encoded value:  betnavmr_tvnagf_ubyqrz
# value organize_giants_holdem 54
# Received type:  rot13
# Received encoded value:  punaaryf_nu_uboovrf
# value channels_ah_hobbies 55
# Received type:  base64
# Received encoded value:  cm9vbV9naV9zZW5zb3Jz
# value room_gi_sensors 56
# Received type:  utf-8
# Received encoded value:  [101, 114, 97, 95, 99, 97, 99, 104, 101, 100, 95, 112, 101, 110, 100, 105, 110, 103]
# value era_cached_pending 57
# Received type:  bigint
# Received encoded value:  0x7468696e675f636f75706f6e735f796f756e676572
# value thing_coupons_younger 58
# Received type:  bigint
# Received encoded value:  0x6d6172735f6164766572746973655f636f6e76657274
# value mars_advertise_convert 59
# Received type:  base64
# Received encoded value:  YWNuZV90cmFpbl9zeW1hbnRlYw==
# value acne_train_symantec 60
# Received type:  hex
# Received encoded value:  776974685f6f72616c5f636f6e7472696275746f72
# value with_oral_contributor 61
# Received type:  rot13
# Received encoded value:  fhofgnaprf_evc_zvyjnhxrr
# value substances_rip_milwaukee 62
# Received type:  bigint
# Received encoded value:  0x6469675f737461745f72657475726e6564
# value dig_stat_returned 63
# Received type:  base64
# Received encoded value:  cmVzdHJpY3RlZF9jcnlzdGFsX2xu
# value restricted_crystal_ln 64
# Received type:  rot13
# Received encoded value:  fcvar_fvfgref_pbybavny
# value spine_sisters_colonial 65
# Received type:  bigint
# Received encoded value:  0x706c617973746174696f6e5f636f6174696e675f656173696c79
# value playstation_coating_easily 66
# Received type:  hex
# Received encoded value:  6d616b6575705f736f6d65686f775f74616b65
# value makeup_somehow_take 67
# Received type:  hex
# Received encoded value:  73696d70736f6e735f6c6f7665645f656d7069726963616c
# value simpsons_loved_empirical 68
# Received type:  bigint
# Received encoded value:  0x636172646966665f677265775f6f70
# value cardiff_grew_op 69
# Received type:  utf-8
# Received encoded value:  [112, 97, 107, 105, 115, 116, 97, 110, 95, 99, 111, 109, 102, 111, 114, 116, 97, 98, 108, 101, 95, 115, 117, 105, 116, 115]
# value pakistan_comfortable_suits 70
# Received type:  bigint
# Received encoded value:  0x617766756c5f6d61726b6572735f706f6c79
# value awful_markers_poly 71
# Received type:  base64
# Received encoded value:  ZmluaXNoZWRfYm9yZGVyc19oZWlnaHQ=
# value finished_borders_height 72
# Received type:  utf-8
# Received encoded value:  [105, 110, 115, 117, 108, 97, 116, 105, 111, 110, 95, 100, 101, 115, 116, 105, 110, 121, 95, 100, 101, 115, 116, 105, 110, 121]
# value insulation_destiny_destiny 73
# Received type:  bigint
# Received encoded value:  0x6261736963735f6672616e63655f686974
# value basics_france_hit 74
# Received type:  bigint
# Received encoded value:  0x6d65646963616c5f726577617264735f77696c6579
# value medical_rewards_wiley 75
# Received type:  rot13
# Received encoded value:  nalobql_jngpurq_wz
# value anybody_watched_jm 76
# Received type:  rot13
# Received encoded value:  qvfrnfr_gheaf_uneyrl
# value disease_turns_harley 77
# Received type:  base64
# Received encoded value:  bGV2ZWxfbWV4aWNhbl9yZWNvbW1lbmQ=
# value level_mexican_recommend 78
# Received type:  hex
# Received encoded value:  7265666572735f736f5f706c65646765
# value refers_so_pledge 79
# Received type:  utf-8
# Received encoded value:  [102, 105, 110, 97, 108, 108, 121, 95, 112, 108, 97, 99, 101, 115, 95, 99, 104, 97, 114, 103, 101, 114]
# value finally_places_charger 80
# Received type:  hex
# Received encoded value:  6e6f76615f736561736f6e5f737465616c
# value nova_season_steal 81
# Received type:  bigint
# Received encoded value:  0x747269756d70685f746f776172645f6261626573
# value triumph_toward_babes 82
# Received type:  bigint
# Received encoded value:  0x74695f636976696c5f63616d70696e67
# value ti_civil_camping 83
# Received type:  bigint
# Received encoded value:  0x7375727265795f7175616c696679696e675f6d6f64656c
# value surrey_qualifying_model 84
# Received type:  hex
# Received encoded value:  666f756768745f73656d65737465725f73757266
# value fought_semester_surf 85
# Received type:  utf-8
# Received encoded value:  [100, 101, 97, 108, 101, 114, 95, 108, 111, 115, 116, 95, 115, 101, 97, 115, 111, 110, 97, 108]
# value dealer_lost_seasonal 86
# Received type:  bigint
# Received encoded value:  0x6a6f625f6d756c74695f656d626564646564
# value job_multi_embedded 87
# Received type:  utf-8
# Received encoded value:  [103, 122, 105, 112, 95, 116, 114, 97, 110, 115, 102, 101, 114, 114, 101, 100, 95, 119, 111, 114, 116, 104, 121]
# value gzip_transferred_worthy 88
# Received type:  base64
# Received encoded value:  cGVuX2NvcGllZF9ob3N0ZWw=
# value pen_copied_hostel 89
# Received type:  base64
# Received encoded value:  c3RyZWFtX3RyYW5zZmVyc19leHByZXNzaW9u
# value stream_transfers_expression 90
# Received type:  bigint
# Received encoded value:  0x6669736865726965735f77656c6c6e6573735f6875676f
# value fisheries_wellness_hugo 91
# Received type:  utf-8
# Received encoded value:  [102, 108, 121, 101, 114, 95, 115, 97, 103, 101, 109, 95, 100, 105, 118, 111, 114, 99, 101]
# value flyer_sagem_divorce 92
# Received type:  base64
# Received encoded value:  bG9naXN0aWNzX2xvZ19hbmQ=
# value logistics_log_and 93
# Received type:  base64
# Received encoded value:  cGVyaW9kX21vdXRoX3dpbGxvdw==
# value period_mouth_willow 94
# Received type:  bigint
# Received encoded value:  0x706561636566756c5f6578616d696e696e675f646d
# value peaceful_examining_dm 95
# Received type:  hex
# Received encoded value:  70757474696e675f61696d735f756e
# value putting_aims_un 96
# Received type:  bigint
# Received encoded value:  0x726570616972735f626f6e5f796561726c79
# value repairs_bon_yearly 97
# Received type:  bigint
# Received encoded value:  0x696e646f6e657369615f61726e6f6c645f6d6f6e6579
# value indonesia_arnold_money 98
# Received type:  rot13
# Received encoded value:  vairagvba_pbafvqrerq_onyv
# value invention_considered_bali 99
# Received type:  crypto{3nc0d3_d3c0d3_3nc0d3}
