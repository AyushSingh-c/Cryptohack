# %%
from sage.all import *
from Crypto.Util.number import bytes_to_long, long_to_bytes

def pc(a,b,c):
    R=IntegerModRing(c)
    x=R(a)
    return x**b

x = [(..., 106979), (..., 108533), (..., 69557), (..., 97117), (..., 103231)]
friend_e = 1
for i in x:
    friend_e = friend_e*i[1]
    
N = ...
e = 0x10001
d = ...
kphi = (e*d)-1
phi = kphi//((kphi//N)+1)

R = IntegerModRing(phi)
friend_d = R(1)/R(friend_e)

c = ...

m = pc(c,friend_d,N)
print(long_to_bytes(Integer(m)))
# Out:
# b'crypto{3ncrypt_y0ur_s3cr3t_w1th_y0ur_fr1end5_publ1c_k3y}'
